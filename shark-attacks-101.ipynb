# %%
import pandas as pd

# had to run `conda install xlrd` to read excel file
shark_df = pd.read_excel('shark-dataset.xls')
df = shark_df

shark_df.head()
# Out:
#                   Date    Year        Type   Country             State  \
# 0  2024-10-14 00:00:00  2024.0  Unprovoked  Honduras              Tela
# 1  2024-10-11 00:00:00  2024.0  Unprovoked       USA           Florida
# 2  2024-09-17 00:00:00  2024.0  Unprovoked  Honduras    Trujillo Colon
# 3  2024-09-16 00:00:00  2024.0  Unprovoked   Morocco  Southern Morocco
# 4  2024-08-26 00:00:00  2024.0  Unprovoked   Jamaica       Montego Bay
#
#                  Location                     Activity  \
# 0               Atlantida                     Swimming
# 1  Brevard County Orlando                      Surfing
# 2         Puerto Castillo         Diving for shellfish
# 3          West of Dakhla  Swimming - jumped off yacht
# 4                Falmouth                 Spearfishing
#
#                        Name Sex Age  ...                  Species   \
# 0  Roberto Carlose Bu Mejia   M  38  ...                Bull shark
# 1            Teddy Witteman   M  16  ...            Bull shark 6ft
# ...

# %%
# Displays all columns
pd.options.display.max_columns = None  

shark_df.head()
# Out:
#                   Date    Year        Type   Country             State  \
# 0  2024-10-14 00:00:00  2024.0  Unprovoked  Honduras              Tela
# 1  2024-10-11 00:00:00  2024.0  Unprovoked       USA           Florida
# 2  2024-09-17 00:00:00  2024.0  Unprovoked  Honduras    Trujillo Colon
# 3  2024-09-16 00:00:00  2024.0  Unprovoked   Morocco  Southern Morocco
# 4  2024-08-26 00:00:00  2024.0  Unprovoked   Jamaica       Montego Bay
#
#                  Location                     Activity  \
# 0               Atlantida                     Swimming
# 1  Brevard County Orlando                      Surfing
# 2         Puerto Castillo         Diving for shellfish
# 3          West of Dakhla  Swimming - jumped off yacht
# 4                Falmouth                 Spearfishing
#
#                        Name Sex Age                                Injury  \
# 0  Roberto Carlose Bu Mejia   M  38  Back and thigh extensive tissue loss
# ...

# %%
# get the number of rows and columns
print(shark_df.shape)
print("List all column names:\n")
print(shark_df.columns)
# Out:
# (6973, 23)
# List all column names:
#
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
# view datatypes
print("\nView datatypes:\n")
print(shark_df.dtypes)
# Out:
# View datatypes:
#
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Unnamed: 11        object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
# get descriptive stats for numerical cols
print("\nView descriptive statistics (numerical columns):\n")
print(shark_df.describe())
# Out:
# View descriptive statistics (numerical columns):
#
#               Year  original order
# count  6971.000000     6799.000000
# mean   1934.776359     3401.152081
# std     272.413746     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2026.000000     6802.000000

# %%
# count missing values in each column
print("\nCount missing values in each column:\n")
print(shark_df.isnull().sum())
# Out:
# Count missing values in each column:
#
# Date                 0
# Year                 2
# Type                18
# Country             50
# State              482
# Location           565
# Activity           586
# Name               220
# Sex                579
# Age               2995
# Injury              35
# Unnamed: 11        562
# Time              3526
# Species           3132
# Source              19
# pdf                174
# href formula       179
# href               177
# Case Number        175
# Case Number.1      176
# original order     174
# Unnamed: 21       6972
# Unnamed: 22       6971
# dtype: int64

# %%
print("Unique values in categorical columns:\n")
# for col in shark_df.select_dtypes(include='object').columns:
#     print(f"{col}: {shark_df[col].unique()}")
# Out:
# Unique values in categorical columns:

# %%
# group data and get summary
summary = shark_df.groupby('Country').size()
print(summary)
# Out:
# Country
#  PHILIPPINES          1
#  TONGA                3
# ADMIRALTY ISLANDS     1
# AFRICA                1
# ALGERIA               1
#                      ..
# VIETNAM              15
# WEST INDIES           2
# WESTERN SAMOA         1
# YEMEN                 2
# YEMEN                 7
# Length: 235, dtype: int64

# %%
print(shark_df['Date'])
# Out:
# 0       2024-10-14 00:00:00
# 1       2024-10-11 00:00:00
# 2       2024-09-17 00:00:00
# 3       2024-09-16 00:00:00
# 4       2024-08-26 00:00:00
#                ...
# 6968            Before 1903
# 6969            Before 1903
# 6970              1900-1905
# 6971              1883-1889
# 6972              1845-1853
# Name: Date, Length: 6973, dtype: object

# %%
# amount of unique values for each column
unique_counts = df.nunique()
print("\nNumber of unique values for each column:")
print(unique_counts)



#code for different counts like top 5 attacks, top 5 sports, etc




sports_count = df["Activity"].value_counts()
top_five_sports = {activity: count for activity, count in sports_count.nlargest(5).items()}
print(f"The top 5 activities are: \n{sports_count}")

atk_count = df["Country"].value_counts()
top_five_most = {country: count for country, count in atk_count.nlargest(5).items()}
top_five_less = {country: count for country, count in atk_count.nsmallest(5).items()}
print(f"The top 5 locations are: \nmost common: {top_five_most} \nless common: {top_five_less}")
# Out:
# Number of unique values for each column:
# Date              6024
# Year               261
# Type                12
# Country            235
# State              916
# Location          4537
# Activity          1597
# Name              5711
# Sex                  8
# Age                245
# Injury            4103
# Unnamed: 11         12
# Time               423
# Species           1695
# Source            5329
# pdf               6789
# href formula      6784
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64
# The top 5 activities are:
# Activity
# Surfing                                                     1125
# Swimming                                                     985
# Fishing                                                      489
# Spearfishing                                                 384
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(12, 6))

# Create the count plot
sns.countplot(data=shark_df, x='Country', order=shark_df['Country'].value_counts().index[:20])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Set title and labels
plt.title('Shark Attacks by Country', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Show the plot
# plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
